# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snsa

# %%
df = pd.read_csv('customer_shopping_data.csv') # store csv into df

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
df.gender.nunique()
# Out:
# 2

# %%
df['gender'].value_counts()
# Out:
# Female    59482
# Male      39975
# Name: gender, dtype: int64

# %%
df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
gender_counts = df['gender'].value_counts()

# Plotting
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['skyblue', 'pink'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
filtered_age = df[(df['age'] >= 18) & (df['age'] <= 69)]['age']

# Plotting the histogram
plt.figure(figsize=(10, 4))
plt.hist(filtered_age, bins=6, color='skyblue', edgecolor='black')
plt.title('Histogram of Age (18 to 69)')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
category_counts = df['category'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Distribution of Categories')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
import numpy as np

plt.figure(figsize=(10, 6))

# Plotting the histogram
sns.histplot(df['price'], bins=30, kde=True, color='skyblue', label='Actual Distribution')

# Overlaying with a normal distribution curve
mu, std = df['price'].mean(), df['price'].std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2, label='Normal Distribution')

plt.title('Distribution of Prices with Normal Distribution Overlay')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
payment_counts = df['payment_method'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Set3.colors)
plt.title('Distribution of Payment Types')
plt.show()

# %%
# Perform one-hot encoding on the 'gender' column
df = pd.get_dummies(df, columns=['gender'], prefix='gender')


print(df)
# Out:
#       invoice_no customer_id  age         category  quantity    price  \
# 0        I138884     C241288   28         Clothing         5  1500.40
# 1        I317333     C111565   21            Shoes         3  1800.51
# 2        I127801     C266599   20         Clothing         1   300.08
# 3        I173702     C988172   66            Shoes         5  3000.85
# 4        I337046     C189076   53            Books         4    60.60
# ...          ...         ...  ...              ...       ...      ...
# 99452    I219422     C441542   45         Souvenir         5    58.65
# 99453    I325143     C569580   27  Food & Beverage         2    10.46
# 99454    I824010     C103292   63  Food & Beverage         2    10.46
# 99455    I702964     C800631   56       Technology         4  4200.00
# 99456    I232867     C273973   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  gender_Female  \
# ...

# %%
# One hot encoding category
df = pd.get_dummies(df, columns=['category'], prefix='category')


print(df)
# Out:
#       invoice_no customer_id  age  quantity    price payment_method  \
# 0        I138884     C241288   28         5  1500.40    Credit Card
# 1        I317333     C111565   21         3  1800.51     Debit Card
# 2        I127801     C266599   20         1   300.08           Cash
# 3        I173702     C988172   66         5  3000.85    Credit Card
# 4        I337046     C189076   53         4    60.60           Cash
# ...          ...         ...  ...       ...      ...            ...
# 99452    I219422     C441542   45         5    58.65    Credit Card
# 99453    I325143     C569580   27         2    10.46           Cash
# 99454    I824010     C103292   63         2    10.46     Debit Card
# 99455    I702964     C800631   56         4  4200.00           Cash
# 99456    I232867     C273973   36         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  gender_Female  gender_Male  \
# 0         5/8/2022            Kanyon              1            0
# ...

# %%
#One hot encoding payment_method
df = pd.get_dummies(df, columns=['payment_method'], prefix='payment_method')

# Display the DataFrame after one-hot encoding
print(df)
# Out:
#       invoice_no customer_id  age  quantity    price invoice_date  \
# 0        I138884     C241288   28         5  1500.40     5/8/2022
# 1        I317333     C111565   21         3  1800.51   12/12/2021
# 2        I127801     C266599   20         1   300.08    9/11/2021
# 3        I173702     C988172   66         5  3000.85   16/05/2021
# 4        I337046     C189076   53         4    60.60   24/10/2021
# ...          ...         ...  ...       ...      ...          ...
# 99452    I219422     C441542   45         5    58.65   21/09/2022
# 99453    I325143     C569580   27         2    10.46   22/09/2021
# 99454    I824010     C103292   63         2    10.46   28/03/2021
# 99455    I702964     C800631   56         4  4200.00   16/03/2021
# 99456    I232867     C273973   36         3    35.19   15/10/2022
#
#           shopping_mall  gender_Female  gender_Male  category_Books  \
# 0                Kanyon              1            0               0
# ...

# %%
df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'age', 'quantity', 'price', 'invoice_date',
#        'shopping_mall', 'gender_Female', 'gender_Male', 'category_Books',
#        'category_Clothing', 'category_Cosmetics', 'category_Food & Beverage',
#        'category_Shoes', 'category_Souvenir', 'category_Technology',
#        'category_Toys', 'payment_method_Cash', 'payment_method_Credit Card',
#        'payment_method_Debit Card'],
#       dtype='object')

# %%
import pandas as pd


# Droping unnecessary columns
columns_to_drop = ['customer_id','invoice_no', 'invoice_date', 'shopping_mall']
df = df.drop(columns=columns_to_drop, axis=1)

# %%
df
# Out:
#        age  quantity    price  gender_Female  gender_Male  category_Books  \
# 0       28         5  1500.40              1            0               0
# 1       21         3  1800.51              0            1               0
# 2       20         1   300.08              0            1               0
# 3       66         5  3000.85              1            0               0
# 4       53         4    60.60              1            0               1
# ...    ...       ...      ...            ...          ...             ...
# 99452   45         5    58.65              1            0               0
# 99453   27         2    10.46              0            1               0
# 99454   63         2    10.46              0            1               0
# 99455   56         4  4200.00              0            1               0
# 99456   36         3    35.19              1            0               0
#
#        category_Clothing  category_Cosmetics  category_Food & Beverage  \
# ...

# %%
df.columns
# Out:
# Index(['age', 'quantity', 'price', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# attributes for heatmap
columns_of_interest = ['age', 'quantity', 'price', 'gender_Female', 'gender_Male',
       'category_Books', 'category_Clothing', 'category_Cosmetics',
       'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
       'category_Technology', 'category_Toys', 'payment_method_Cash',
       'payment_method_Credit Card', 'payment_method_Debit Card']


correlation_df = df[columns_of_interest]


correlation_matrix = correlation_df.corr()

# Visualisation 
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


num_components = 12  # We trialed and error to see where the variance diminishes instantly.

# Select the features for PCA
features_for_pca = ['age', 'quantity', 'price', 'gender_Female', 'gender_Male',
       'category_Books', 'category_Clothing', 'category_Cosmetics',
       'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
       'category_Technology', 'category_Toys', 'payment_method_Cash',
       'payment_method_Credit Card', 'payment_method_Debit Card']

# Standardize the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features_for_pca])

# Apply PCA
pca = PCA(n_components=num_components)
df_pca = pca.fit_transform(df_scaled)

# Add PCA results to the DataFrame
for i in range(num_components):
    df[f'pca{i + 1}'] = df_pca[:, i]

# Scree plot to visualize explained variance
explained_var_ratio = pca.explained_variance_ratio_
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(explained_var_ratio) + 1), explained_var_ratio.cumsum(), marker='o', linestyle='--')
plt.title('Scree Plot - Explained Variance Ratio')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.show()


#df_new = df_3.copy()


#print(df_new.head())

# %%
#Same figure but with more pca to prove a point about 12 being the ideal number.
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt


pca = PCA()
pca.fit(df_scaled)

# Plot the explained variance ratio
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_) + 1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Explained Variance Ratio')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.show()

# %%
df.head
# Out:
# <bound method NDFrame.head of        age  quantity    price  gender_Female  gender_Male  category_Books  \
# 0       28         5  1500.40              1            0               0
# 1       21         3  1800.51              0            1               0
# 2       20         1   300.08              0            1               0
# 3       66         5  3000.85              1            0               0
# 4       53         4    60.60              1            0               1
# ...    ...       ...      ...            ...          ...             ...
# 99452   45         5    58.65              1            0               0
# 99453   27         2    10.46              0            1               0
# 99454   63         2    10.46              0            1               0
# 99455   56         4  4200.00              0            1               0
# 99456   36         3    35.19              1            0               0
#
# ...

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns


# Select features for clustering
features_for_clustering = ['pca2','pca8'] # This gave the least expected number of optimal k.

# Standardize the features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features_for_clustering])

# Determine the number of clusters using the elbow method
inertia = []
for n_clusters in range(1, 11):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

# Plot the elbow curve 
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), inertia, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# Based on the elbow method, choose the optimal number of clusters (k)
k_optimal = 2  # Update this based on the elbow plot

# Apply K-Means clustering
kmeans = KMeans(n_clusters=k_optimal, random_state=42)
df['cluster'] = kmeans.fit_predict(df_scaled)




# Visualize the clusters using a scatter plot
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df, x='pca2', y='pca8', hue='cluster', palette='viridis', s=50)
plt.title('Clusters Visualized with PCA Components')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 1')
plt.legend(title='Cluster')
plt.show()

# Check the cluster distribution
print("Cluster Distribution:")
print(df['cluster'].value_counts())
# Out:
# Cluster Distribution:
# 1    59482
# 0    39975
# Name: cluster, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'quantity', 'price', 'gender_Female', 'gender_Male',
#        'category_Books', 'category_Clothing', 'category_Cosmetics',
#        'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
#        'category_Technology', 'category_Toys', 'payment_method_Cash',
#        'payment_method_Credit Card', 'payment_method_Debit Card', 'pca1',
#        'pca2', 'pca3', 'pca4', 'pca5', 'pca6', 'pca7', 'pca8', 'pca9', 'pca10',
#        'pca11', 'pca12', 'cluster'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    age  quantity    price  gender_Female  gender_Male  category_Books  \
# 0   28         5  1500.40              1            0               0
# 1   21         3  1800.51              0            1               0
# 2   20         1   300.08              0            1               0
# 3   66         5  3000.85              1            0               0
# 4   53         4    60.60              1            0               1
# 5   28         5  1500.40              1            0               0
# 6   49         1    40.66              1            0               0
# 7   32         2   600.16              1            0               0
# 8   69         3   900.24              0            1               0
# 9   60         2   600.16              1            0               0
#
#    category_Clothing  category_Cosmetics  category_Food & Beverage  \
# 0                  1                   0                         0
# ...

# %%
len(y_test), len(y_pred)
# Out:
# (79565, 79566)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix


'''X_data = df_new[['quantity', 'price', 'category_Books', 'category_Clothing',
       'category_Cosmetics', 'category_Food & Beverage', 'category_Shoes',
       'category_Souvenir', 'category_Technology', 'category_Toys']]
       
       '''
X_data = df[['age', 'quantity', 'price', 'gender_Female', 'gender_Male',
       'category_Books', 'category_Clothing', 'category_Cosmetics',
       'category_Food & Beverage', 'category_Shoes', 'category_Souvenir',
       'category_Technology', 'category_Toys', 'payment_method_Cash',
       'payment_method_Credit Card', 'payment_method_Debit Card']]

                
                
y = df['cluster']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.20, random_state=500)


X_train.to_csv('train_data.csv', index=False)
X_test.to_csv('test_data.csv', index=False)
y_train.to_csv('train_labels.csv', index=False)
y_test.to_csv('test_labels.csv', index=False)

# %%
X_train = pd.read_csv('train_data.csv')
X_test = pd.read_csv('test_data.csv')
y_train = pd.read_csv('train_labels.csv')
y_test = pd.read_csv('test_labels.csv')

# %%
y_test
# Out:
#        cluster
# 0            1
# 1            1
# 2            0
# 3            1
# 4            0
# ...        ...
# 79561        1
# 79562        0
# 79563        0
# 79564        0
# 79565        0
#
# [79566 rows x 1 columns]

# %%
# Choose a model (Decision Tree as an example)
model = DecisionTreeClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# %%
# Evaluate the model using the original labels
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.71967322725787394

# %%
# Choose a model (Logistic Regression as an example)
model = LogisticRegression(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# C:\Users\aksha\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 0.6762193074105823
# C:\Users\aksha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Choose a model (Random Forest as an example)
model = RandomForestClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_34624\1134116041.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train, y_train)
# Accuracy: 0.8903393409245155

# %%
# Thus this concludes our project.

# %%
'''

 Key Findings:

-The dataset was thoroughly examined, revealing patterns, trends, and relationships between various features such as age, quantity, price, and payment methods.
-Utilizing one-hot encoding, principal component analysis (PCA), and clustering techniques, we identified distinct customer segments and reduced the dimensionality of the dataset.
-Machine learning models, including Decision Tree, Logistic Regression, and Random Forest, were trained and evaluated for their ability to predict premium customer capability.

Insights:

-Clustering analysis provided a valuable segmentation of customers, highlighting distinct groups based on their behavior.
-Principal component analysis aided in dimensionality reduction, capturing essential features that contribute to premium customer classification.

Model Performance:

-The models exhibited varying degrees of accuracy, with Random Forest outperforming others in predicting premium customer capability.
-Confusion matrices provided a detailed breakdown of model predictions, offering insights into true positives, true negatives, false positives, and false negatives.

Recommendations:

-Based on the analysis, the Random Forest model demonstrated promising results for predicting premium customer capability.
-Further refinement of the model, including feature engineering and hyperparameter tuning, could potentially enhance predictive accuracy.

'''
